# %%
import pandas as pd
import matplotlib.pyplot as plt
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import numpy as np

# %%
# Financial analysis
tokenizer = AutoTokenizer.from_pretrained("mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis")
model = AutoModelForSequenceClassification.from_pretrained("mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis")

# %%
# Function to perform sentiment analysis and get a continuous score between -1 and 1
def analyze_sentiment(sentence):
    inputs = tokenizer(sentence, return_tensors="pt", truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    logits = outputs.logits
    probabilities = torch.nn.functional.softmax(logits, dim=-1).numpy()[0]
    score = probabilities[2] - probabilities[0]  # positive probability - negative probability
    return score

# %%
df = pd.read_csv("preprocessed_data/preprocessed.csv")

# %%
df['financial_sentiment'] = df['summary'].apply(analyze_sentiment)

# %%
df
# Out:
#                datetime                                               body  \
# 0   2024-05-16 15:55:44  [1] https://alleyesonwagner.org/2024/05/10/med...
# 1   2024-05-20 16:08:07  ENERTIME (FR0011915339 - ALENE), a French comp...
# 2   2024-05-20 16:32:24  ENERTIME (FR0011915339 - ALENE), a French comp...
# 3   2024-05-22 17:13:59  ... All right here. Subscribe now atCRAVE.CA. ...
# 4   2024-05-26 04:56:32  Our hero Paul lovesto help others.But today, ....
# 5   2024-05-26 15:50:35  israel and jewish affairs. Issuing a statement...
# 6   2024-05-26 18:10:20  station with a suspended license. Officers wer...
# 7   2024-05-26 18:41:04  number of violent incidents that canadians are...
# 8   2024-05-26 19:16:23  when you get through, you can turn the sign of...
# 9   2024-05-26 19:19:20  match at the world hockey championship. Here's...
# 10  2024-05-26 23:08:38  >>> It's been one month since flash flooding d...
# 11  2024-05-27 00:17:13  them and take them seriously, which they say h...
# 12  2024-05-27 06:47:50  exploding with magic. She stop magic was wonde...
# 13  2024-05-27 07:51:46  undeveloped lot much to the delight of the nei...
# 14  2024-05-27 09:16:15  those moments might also be for the adults who...
# 15  2024-05-27 09:45:51  going to so the tickets worth about me going t...
# 16  2024-05-27 15:23:05  events also happen. And we had an earlier stat...
# 17  2024-05-27 18:07:20  police unveiling today results of a major auto...
# 18  2024-05-27 20:48:34  digging with their hands with sticks with with...
# 19  2024-05-30 18:51:16  Higher education, media, and culture exchanges...
#
#                                               summary  financial_sentiment
# 0   Russia is shifting its military posture in the...             0.014597
# 1   ENERTIME is ranked 5th out of 200 companies ov...             0.000045
# 2   ENERTIME is a French company specializing in "...             0.000013
# 3   Canada warns that we have reached a critical p...            -0.996267
# 4   Cold plunging after lifting weights can slow m...             0.986784
# 5   The montreal alouettes have defeated the toron...            -0.625594
# 6   The montreal alouettes, they defeated toronto ...             0.999058
# 7   Canada took on sweden in the bronze medal matc...            -0.000022
# 8   Militant group says it launched a barrage of p...            -0.000175
# 9   The montreal alouettes defeated toronto argona...            -0.951547
# 10  Flash flooding in nova scotia caused more than...            -0.973335
# 11  A rally was held in the beaches today to deman...            -0.003306
# 12  More than four thousand guests were served thr...            -0.000009
# 13  Inaugural "wee wild ones diaper dash" Saw 64 b...            -0.000014
# 14  The inaugural "wee wild ones diaper dash" saw ...            -0.000509
# 15  Seniors Choice are the #1 Direct Choice for Ca...            -0.000439
# 16  The U.N. refugee agency, unwra. has posted on ...            -0.992512
# 17  Spain and I are poised to officially recognize...             0.000046
# 18  Residents in fort nelson, british columbia wil...            -0.002402
# 19  China is the second most popular destination f...             0.000591

# %%
df.to_csv("processed_data/processed_data.csv")
